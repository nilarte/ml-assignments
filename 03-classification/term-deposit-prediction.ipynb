# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_full = pd.read_csv('bank-full.csv')
df_full
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
selected_columns = [
    'age', 'job', 'marital', 'education', 'balance', 
    'housing', 'contact', 'day', 'month', 'duration', 
    'campaign', 'pdays', 'previous', 'poutcome', 'y'
]

# Select the desired columns
df = df_full[selected_columns]
df
# Out:
#        age           job   marital  education  balance housing    contact  \
# 0       58    management   married   tertiary     2143     yes    unknown
# 1       44    technician    single  secondary       29     yes    unknown
# 2       33  entrepreneur   married  secondary        2     yes    unknown
# 3       47   blue-collar   married    unknown     1506     yes    unknown
# 4       33       unknown    single    unknown        1      no    unknown
# ...    ...           ...       ...        ...      ...     ...        ...
# 45206   51    technician   married   tertiary      825      no   cellular
# 45207   71       retired  divorced    primary     1729      no   cellular
# 45208   72       retired   married  secondary     5715      no   cellular
# 45209   57   blue-collar   married  secondary      668      no  telephone
# 45210   37  entrepreneur   married  secondary     2971      no   cellular
#
#        day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# balance      0
# housing      0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
# Find the mode (most frequent value) for the 'education' column
education_mode = df['education'].mode()[0]
print(f"\nMost frequent observation (mode) in 'education': {education_mode}")
# Out:
# Most frequent observation (mode) in 'education': secondary

# %%
import pandas as pd

# Select only the numerical features from the DataFrame
numerical_df = df.select_dtypes(include=['int64', 'float64'])

# Compute the correlation matrix
correlation_matrix = numerical_df.corr()

# Display the correlation matrix
print("Correlation Matrix:\n", correlation_matrix)

# Find the two features with the highest correlation (excluding self-correlation)
correlation_matrix_unstacked = correlation_matrix.unstack()
sorted_correlations = correlation_matrix_unstacked.sort_values(ascending=False)

# Exclude self-correlations (where feature correlates with itself)
top_correlated_pair = sorted_correlations[sorted_correlations < 1].idxmax()
highest_correlation = sorted_correlations[sorted_correlations < 1].max()

print(f"\nThe two most correlated features are: {top_correlated_pair}")
print(f"With a correlation coefficient of: {highest_correlation}")
# Out:
# Correlation Matrix:
#                 age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000
#
# The two most correlated features are: ('previous', 'pdays')
# With a correlation coefficient of: 0.4548196354805043

# %%
df.y = (df.y == 'yes').astype(int)
# Out:
# /tmp/ipykernel_1640462/2311194752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.y = (df.y == 'yes').astype(int)

# %%
from sklearn.model_selection import train_test_split
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)
len(df_train), len(df_val), len(df_test)
# Out:
# (27126, 9042, 9043)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
y_train = df_train.y.values
y_val = df_val.y.values
y_test = df_test.y.values

del df_train['y']
del df_val['y']
del df_test['y']

# %%
from sklearn.metrics import mutual_info_score
mutual_info_score(y_train, df_train.contact).round(2)
# Out:
# 0.01

# %%
mutual_info_score(y_train, df_train.education).round(2)
# Out:
# 0.0

# %%
mutual_info_score(y_train, df_train.housing).round(2)
# Out:
# 0.01

# %%
mutual_info_score(y_train, df_train.poutcome).round(2)
# Out:
# 0.03

# %% [markdown]
# One-hot encoding

# %%
from sklearn.feature_extraction import DictVectorizer

dv = DictVectorizer(sparse=False)


#numerical = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

numerical = ['age', 'day', 'duration', 'campaign', 'pdays', 'previous']

categorical = ['job', 'marital', 'education', 'housing', 'contact',  'month', 'poutcome']

# categorical = ['job', 'education', 'housing', 'contact',  'month', 'poutcome']

train_dict = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %% [markdown]
# Training logistic regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
y_pred = model.predict_proba(X_val)[:, 1]
term_deposit_decision = (y_pred >= 0.5)
(y_val == term_deposit_decision).mean()
# Out:
# 0.9007962840079629
